# %% [markdown]
# <a href="https://colab.research.google.com/github/RAVITEJA-VADLURI/DATA-MINING-BATCH--12/blob/main/Wine(1)_1942_21_2_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load dataset from file
df = pd.read_csv('/content/WineQT.csv')

# Separating features and target variable
X = df.drop(columns=['quality', 'Id'])
y = df['quality']

# Standardizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Applying PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Visualizing the PCA components
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k', s=100)
plt.title('PCA of Wine Quality Dataset (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Quality')
plt.show()

# Display explained variance ratio
print("Explained Variance Ratio of Each Component:")
print(pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio of Each Component:
# [0.28692345 0.17075104]
